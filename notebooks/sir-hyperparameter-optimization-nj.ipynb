# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("../sir_hyperparameter_optimization.csv", index_col=0)

# %%
df.head()
# Out:
#            MAE  window  distancing_reduction  recovery_days
# 0  3858.948226       1                  0.01              1
# 1  4221.235358       1                  0.01              3
# 2  4285.669796       1                  0.01              5
# 3  4328.600115       1                  0.01             10
# 4  4339.820981       1                  0.01             14

# %% [markdown]
# # Hyperparameters with Lowest MAE

# %%
df.sort_values("MAE").head(10)
# Out:
#              MAE  window  distancing_reduction  recovery_days
# 224  3684.802170      10                  0.23              1
# 154  3686.481572       5                  0.23              1
# 84   3686.849381       3                  0.23              1
# 294  3687.262098      14                  0.23              1
# 371  3692.875837      20                  0.34              1
# 301  3694.297796      14                  0.34              1
# 14   3696.819751       1                  0.23              1
# 231  3697.649318      10                  0.34              1
# 364  3698.365255      20                  0.23              1
# 161  3702.183674       5                  0.34              1

# %%
fig = px.scatter(df, x="recovery_days", y="distancing_reduction", size="window", color="MAE", size_max=df["window"].max())
fig.show()
# Out:
# <div>
#
#
#             <div id="86c8e22f-a14b-4c8a-8f5e-420e1fbf8dcf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("86c8e22f-a14b-4c8a-8f5e-420e1fbf8dcf")) {
#                     Plotly.newPlot(
#                         '86c8e22f-a14b-4c8a-8f5e-420e1fbf8dcf',
# ...
